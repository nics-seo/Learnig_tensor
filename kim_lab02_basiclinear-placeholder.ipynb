# %%
import tensorflow as tf
import numpy as np

# %%
# X와 Y 데이터
#x_train = [1, 2, 3]
#y_train = [1, 2, 3]


W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

# X와 Y 데이터를 사용할 수 있는 장소(place)를 이용할 수 있다.
#한 텐서에 해당하는 placeholder는 항상 feed_dict에서 불러올 수 있음
# See http://stackoverflow.com/questions/36693740/
X = tf.placeholder(tf.float32, shape=[None])
Y = tf.placeholder(tf.float32, shape=[None])

# WX + b 가설
hypothesis = X * W + b

# %%
#Cost/Loss 함수
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
#최소화를 함(Minimize)
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

# %%
# 세션에 그래프를 구동시킴
sess = tf.Session()
# 그래프에 전역변수(global variables)를 초기화 시킴
sess.run(tf.global_variables_initializer())

# %%
# 선을 맞춤(Fit the line)
for step in range(2001):
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train],
                                         feed_dict={X: [1, 2, 3, 4, 5], Y: [2.1, 3.1, 4.1, 5.1, 6.1]})
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 1.20958 [ 1.00026441] [-0.00060071]
# 20 0.166129 [ 1.26332474] [ 0.14434683]
# 40 0.145064 [ 1.24726772] [ 0.20726246]
# 60 0.126685 [ 1.23107934] [ 0.26573005]
# 80 0.110635 [ 1.21594584] [ 0.32036704]
# 100 0.0966185 [ 1.20180333] [ 0.37142575]
# 120 0.0843778 [ 1.18858707] [ 0.4191407]
# 140 0.0736877 [ 1.17623651] [ 0.46373066]
# 160 0.064352 [ 1.16469443] [ 0.50540048]
# 180 0.0561991 [ 1.15390837] [ 0.54434144]
# 200 0.0490791 [ 1.14382887] [ 0.58073181]
# 220 0.0428611 [ 1.13440955] [ 0.61473912]
# 240 0.0374309 [ 1.12560689] [ 0.64651924]
# 260 0.0326887 [ 1.11738074] [ 0.67621809]
# 280 0.0285473 [ 1.10969329] [ 0.70397192]
# 300 0.0249306 [ 1.10250962] [ 0.72990805]
# 320 0.0217721 [ 1.09579611] [ 0.75414568]
# 340 0.0190137 [ 1.08952224] [ 0.77679598]
# 360 0.0166048 [ 1.08365941] [ 0.79796278]
# 380 0.0145011 [ 1.07818043] [ 0.81774354]
# 400 0.0126639 [ 1.07306051] [ 0.83622873]
# 420 0.0110595 [ 1.06827557] [ 0.85350335]
# 440 0.00965833 [ 1.06380415] [ 0.86964667]
# 460 0.00843471 [ 1.05962563] [ 0.88473254]
# 480 0.00736609 [ 1.05572069] [ 0.89883047]
# 500 0.00643286 [ 1.05207157] [ 0.91200513]
# 520 0.00561786 [ 1.04866135] [ 0.92431712]
# 540 0.00490613 [ 1.04547441] [ 0.93582273]
# 560 0.00428455 [ 1.04249632] [ 0.94657481]
# 580 0.00374173 [ 1.03971314] [ 0.95662272]
# 600 0.00326768 [ 1.03711236] [ 0.9660126]
# 620 0.0028537 [ 1.03468192] [ 0.97478741]
# 640 0.00249217 [ 1.0324105] [ 0.98298764]
# 660 0.00217642 [ 1.03028774] [ 0.99065089]
# 680 0.00190068 [ 1.02830434] [ 0.99781227]
# 700 0.00165988 [ 1.02645075] [ 1.00450456]
# 720 0.00144959 [ 1.0247184] [ 1.01075864]
# 740 0.00126593 [ 1.02309954] [ 1.01660311]
# 760 0.00110556 [ 1.02158689] [ 1.02206481]
# 780 0.00096549 [ 1.02017307] [ 1.02716887]
# 800 0.000843158 [ 1.01885188] [ 1.03193879]
# 820 0.000736343 [ 1.01761723] [ 1.03639591]
# 840 0.00064305 [ 1.0164634] [ 1.04056168]
# 860 0.000561578 [ 1.01538527] [ 1.04445434]
# 880 0.000490438 [ 1.01437771] [ 1.04809177]
